# %%
import platform

# %%
platform.platform()
# Out:
# 'Linux-6.1.85+-x86_64-with-glibc2.35'

# %%
# %cd drive/MyDrive/VNP46A4/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/VNP46A4/'
# /content/drive/MyDrive/VNP46A4

# %%
# !ls
# Out:
# LAADS_query.2025-02-11T11_20.csv

# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
file_path = 'LAADS_query.2025-02-11T11_20.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)
column_name = "fileUrls from query VNP46A4--5000 2011-12-01..2025-02-11 x-157.7y67.7 x-54.5y18.5[7]"
edl_token = 'eyJ0eXAiOiJKV1QiLCJvcmlnaW4iOiJFYXJ0aGRhdGEgTG9naW4iLCJzaWciOiJlZGxqd3RwdWJrZXlfb3BzIiwiYWxnIjoiUlMyNTYifQ.eyJ0eXBlIjoiVXNlciIsInVpZCI6ImFiaGluYXZnMjEiLCJleHAiOjE3NDM4MzAzODIsImlhdCI6MTczODY0NjM4MiwiaXNzIjoiaHR0cHM6Ly91cnMuZWFydGhkYXRhLm5hc2EuZ292IiwiaWRlbnRpdHlfcHJvdmlkZXIiOiJlZGxfb3BzIiwiYWNyIjoiZWRsIiwiYXNzdXJhbmNlX2xldmVsIjozfQ.lhHWunRPjTj1CCntvjOFysBXNAX-68QVgWLgR9RqK9B4m3pHXD8mravzJNwpIHg0PVDzddyffdPzUdjEk0tvz-azcQFt0x4TVuVBu9bjqTacoZ1wvKc9C89mwBYrPEdAXjhFAn5hNhsNrgalwpm1H7nx98kevL8ILnnyS-IaU9XSuvpns0G6fKifDPjj8mDusoYmZwJ5fZ0hxC2ePAA98Sq8gQl3CZNqwQirmEJKVXMekTX3VbXMpqUexfEF8555r1p0uAHD_bvGDSRS9o1F6qQ_j_6BAjaAor8oaY5XX4l15axxMKhK6tIxAt2KVLO6nulGSTM-PaTk5ZmjRnWbGA'

# Display the first few rows of the DataFrame to verify it's loaded correctly
# print(df.head())

# Access the specific column
# file_urls = df[column_name]

# Display the first few entries in the column
# print(file_urls.head())

# %%
for url in df[column_name]:
    # Construct the wget command
    command = f'wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=3 "{url}" --header "Authorization: Bearer {edl_token}" -P .'

    # Run the wget command
    try:
        print(f"Downloading: {url}")
        # !{command}
    except Exception as e:
        print(f"Failed to download {url}: {e}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Downloaded: 1 files, 14M in 2.1s (6.73 MB/s)
# Downloading: https://ladsweb.modaps.eosdis.nasa.gov/api/v2/content/archives/VNP46A4.A2018001.h06v05.001.2021119041113.h5
# --2025-02-11 13:44:13--  https://ladsweb.modaps.eosdis.nasa.gov/api/v2/content/archives/VNP46A4.A2018001.h06v05.001.2021119041113.h5
# Resolving ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)... 198.118.194.40, 2001:4d0:241a:40c0::40
# Connecting to ladsweb.modaps.eosdis.nasa.gov (ladsweb.modaps.eosdis.nasa.gov)|198.118.194.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21745731 (21M) [application/octet-stream]
# Saving to: ‘./archives/VNP46A4.A2018001.h06v05.001.2021119041113.h5’
#
# archives/VNP46A4.A2 100%[===================>]  20.74M  7.47MB/s    in 2.8s
#
# 2025-02-11 13:44:17 (7.47 MB/s) - ‘./archives/VNP46A4.A2018001.h06v05.001.2021119041113.h5’ saved [21745731/21745731]
#
# ...

# %%
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 132664 (130K)
# Saving to: ‘./VNP46A2/2018/053/VNP46A2.A2018053.h21v16.001.2020331004811.h5’
#
# VNP46A2/2018/053/VN 100%[===================>] 129.55K  --.-KB/s    in 0.01s
#
# 2025-02-04 11:20:20 (13.0 MB/s) - ‘./VNP46A2/2018/053/VNP46A2.A2018053.h21v16.001.2020331004811.h5’ saved [132664/132664]
#
# --2025-02-04 11:20:20--  https://ladsweb.modaps.eosdis.nasa.gov/archive/allData/5000/VNP46A2/2018/053/VNP46A2.A2018053.h22v02.001.2020331133054.h5
# Reusing existing connection to ladsweb.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3024743 (2.9M)
# Saving to: ‘./VNP46A2/2018/053/VNP46A2.A2018053.h22v02.001.2020331133054.h5’
#
# VNP46A2/2018/053/VN 100%[===================>]   2.88M  --.-KB/s    in 0.04s
#
# 2025-02-04 11:20:21 (70.0 MB/s) - ‘./VNP46A2/2018/053/VNP46A2.A2018053.h22v02.001.2020331133054.h5’ saved [3024743/3024743]
#
# ...
